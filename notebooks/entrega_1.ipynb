# %% [markdown]
# # TP Integrador - Entrega 1
#
# ## Análisis de Siniestros Viales
#
# **Materia:** Ciencia de Datos
# **Grupo 10:** Sonia Ferreyra, Sofia Roda, Octavio Amuchastegui, Hernan Moyano
# **Dataset:** Siniestros Viales

# %% [markdown]
# ## Importación de librerías

# %%
import sys
sys.path.append('../src')
from data_cleaning import load_data

# %% [markdown]
# ## Carga de datos

# %%
df = load_data('../data/raw/siniestros_viales_hechos.xlsx')
df.head()

# %% [markdown]
# ## Comprensión del negocio

# %% [markdown]
# ## Comprensión de los datos

# %% [markdown]
# ## Exploración inicial

# %% [markdown]
# ## Tipos de variables

# %% [markdown]
# ## Calidad de los datos

# %% [markdown]
# ## Análisis preliminar

# %% [markdown]
# ## Justificación del dataset

# %% [markdown]
# ## Conclusión
