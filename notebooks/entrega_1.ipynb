# %% [markdown]
# # Entrega 1
#
# Exploración y limpieza de datos.

# %%
import pandas as pd
import sys
sys.path.append('../src')
from data_cleaning import load_data, drop_duplicates, drop_missing, fill_missing
